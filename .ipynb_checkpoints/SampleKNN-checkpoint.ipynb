# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=5)

df = pd.read_csv("sample.csv")

# %%
df.head(20)
# Out:
#     Width  Length        Insect
# 0    2.30    8.56  Stick Insect
# 1    3.43    7.68  Stick Insect
# 2    1.32   12.32  Stick Insect
# 3    2.34    9.45  Stick Insect
# 4    1.87    7.45  Stick Insect
# 5    3.76   10.22  Stick Insect
# 6    1.65    9.43  Stick Insect
# 7    2.87    9.43  Stick Insect
# 8    3.00   10.56  Stick Insect
# 9    7.68    2.43      LadyBird
# 10   6.45    1.23      LadyBird
# 11   9.56    0.78      LadyBird
# 12   5.34    2.67      LadyBird
# 13   8.21    4.21      LadyBird
# 14   7.54    1.88      LadyBird
# 15   6.77    3.56      LadyBird
# 16   9.00    2.56      LadyBird
# 17   8.00    2.00      LadyBird
# 18   2.31   11.00  Stick Insect
# 19   7.00    4.50      LadyBird

# %%
heading = "Insect"
labelencoder = LabelEncoder()
df["Insect"] = labelencoder.fit_transform(df["Insect"])
insects = np.array(df["Insect"])

# %%
df.head(20)
# Out:
#     Width  Length  Insect
# 0    2.30    8.56       1
# 1    3.43    7.68       1
# 2    1.32   12.32       1
# 3    2.34    9.45       1
# 4    1.87    7.45       1
# 5    3.76   10.22       1
# 6    1.65    9.43       1
# 7    2.87    9.43       1
# 8    3.00   10.56       1
# 9    7.68    2.43       0
# 10   6.45    1.23       0
# 11   9.56    0.78       0
# 12   5.34    2.67       0
# 13   8.21    4.21       0
# 14   7.54    1.88       0
# 15   6.77    3.56       0
# 16   9.00    2.56       0
# 17   8.00    2.00       0
# 18   2.31   11.00       1
# 19   7.00    4.50       0

# %%
kf = KFold(n_splits=10, shuffle=True)

# %%
error = []
for train, test in kf.split(df):
    predict_columns = df[["Width", "Length"]].iloc[train,:]
    x_train = np.array(predict_columns).reshape(-1, 1)
    target_column = df["Insect"].iloc[train]
    y_train = np.array(target_column).reshape(-1, 1)
    outcome = df["Insect"].iloc[test]
    y_test = np.array(outcome).reshape(-1, 1)
    print (x_train)
# Out:
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 1.87]
#  [ 7.45]
#  [ 3.76]
#  [10.22]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]
#  [ 7.  ]
#  [ 4.5 ]]
# [[ 2.3 ]
#  [ 8.56]
#  [ 3.43]
#  [ 7.68]
#  [ 1.32]
#  [12.32]
#  [ 2.34]
#  [ 9.45]
#  [ 3.76]
#  [10.22]
#  [ 1.65]
#  [ 9.43]
#  [ 2.87]
#  [ 9.43]
#  [ 3.  ]
#  [10.56]
#  [ 7.68]
#  [ 2.43]
#  [ 6.45]
#  [ 1.23]
#  [ 9.56]
#  [ 0.78]
#  [ 5.34]
#  [ 2.67]
#  [ 8.21]
#  [ 4.21]
#  [ 7.54]
#  [ 1.88]
#  [ 6.77]
#  [ 3.56]
#  [ 9.  ]
#  [ 2.56]
#  [ 8.  ]
#  [ 2.  ]
#  [ 2.31]
#  [11.  ]]

# %%
def classification_model(model, data, predictors, outcome):
    """
    model.fit(data[predictors], data[outcome])
    predictions = model.predict(data[predictors])
    print(predictions)
    """
    kf = KFold(n_splits=10, shuffle=True)
    for train, test in kf.split(df):
        # Filter training data
        train_predictors = (data[predictors].iloc[train,:]).values
        print(train_predictors)
        # The target we're using to train the algorithm.
        train_target = data[outcome].iloc[train]

        # Training the algorithm using the predictors and target.
        model.fit(train_predictors, train_target)

# %%
outcome_var = "Insect"
model = knn
predictor_var = ["Width", "Length"]
classification_model(model, df, predictor_var, outcome_var)
model.predict([0.9, 0.8])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-07c672302b10> in <module>()
#       2 model = knn
#       3 predictor_var = ["Width", "Length"]
# ----> 4 classification_model(model, df, predictor_var, outcome_var)
#       5 model.predict([0.9, 0.8])
#
# <ipython-input-135-67ec104b7897> in classification_model(model, data, predictors, outcome)
#       8     for train, test in kf.split(df):
#       9         # Filter training data
# ---> 10         train_predictors = (data[predictors].iloc[[train],:])
#      11
#      12         # The target we're using to train the algorithm.
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2027                 continue
#    2028
# -> 2029             retval = getattr(retval, self.name)._getitem_axis(key, axis=axis)
#    2030
#    2031             # if the dim was reduced, then pass a lower-dim the next time
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2089         # a list of integers
#    2090         elif is_list_like_indexer(key):
# -> 2091             return self._get_list_axis(key, axis=axis)
#    2092
#    2093         # a single integer
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    2068             axis = self.axis or 0
#    2069         try:
# -> 2070             return self.obj._take(key, axis=axis)
#    2071         except IndexError:
#    2072             # re-raise with different error message
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    2787         new_data = self._data.take(indices,
#    2788                                    axis=self._get_block_manager_axis(axis),
# -> 2789                                    verify=True)
#    2790         result = self._constructor(new_data).__finalize__(self)
#    2791
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals.py in take(self, indexer, axis, verify, convert)
#    4537         new_labels = self.axes[axis].take(indexer)
#    4538         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 4539                                     axis=axis, allow_dups=True)
#    4540
#    4541     def merge(self, other, lsuffix='', rsuffix=''):
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    4423             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    4424                 fill_value if fill_value is not None else blk.fill_value,))
# -> 4425                 for blk in self.blocks]
#    4426
#    4427         new_axes = list(self.axes)
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    4423             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    4424                 fill_value if fill_value is not None else blk.fill_value,))
# -> 4425                 for blk in self.blocks]
#    4426
#    4427         new_axes = list(self.axes)
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1256             fill_value = fill_tuple[0]
#    1257             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1258                                        allow_fill=True, fill_value=fill_value)
#    1259
#    1260         if new_mgr_locs is None:
#
# c:\users\john rey juele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1657     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#    1658                                  mask_info=mask_info)
# -> 1659     func(arr, indexer, out, fill_value)
#    1660
#    1661     if flip_order:
#
# pandas\_libs\algos_take_helper.pxi in pandas._libs.algos.take_2d_axis1_float64_float64()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %%
kf = KFold(n_splits=10, shuffle=True)
for train, test in kf.split(df):
    # Filter training data
    train_predictors = (df[["Width", "Length"]].iloc[train,:]).values
    # The target we're using to train the algorithm.
    train_target = df["Insect"].iloc[train].values

    # Training the algorithm using the predictors and target.
    knn.fit(train_predictors, train_target)

# %%
knn.predict([[4, 6.5]])
# Out:
# array([1.])

# %%
df.head(20)
# Out:
#     Width  Length  Insect
# 0    2.30    8.56       1
# 1    3.43    7.68       1
# 2    1.32   12.32       1
# 3    2.34    9.45       1
# 4    1.87    7.45       1
# 5    3.76   10.22       1
# 6    1.65    9.43       1
# 7    2.87    9.43       1
# 8    3.00   10.56       1
# 9    7.68    2.43       0
# 10   6.45    1.23       0
# 11   9.56    0.78       0
# 12   5.34    2.67       0
# 13   8.21    4.21       0
# 14   7.54    1.88       0
# 15   6.77    3.56       0
# 16   9.00    2.56       0
# 17   8.00    2.00       0
# 18   2.31   11.00       1
# 19   7.00    4.50       0
