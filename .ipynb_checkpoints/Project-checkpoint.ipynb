# %% [markdown]
# # Imports <a id="imports"></a>
# This cell will contain the imports necessary for the project

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np

"""
repair.py contains functions that helpes with repairing dataset and performing
data munging
"""
import repair

# %%
df = pd.read_csv("googleplaystore.csv")

# %% [markdown]
# # The Dataset <a id="ds"></a>
# The dataset we chose is the ["Google Play Store Apps"](https://www.kaggle.com/lava18/google-play-store-apps) dataset with around 10,841 data rows.
#
# ## The Headings <a id="hd"></a>
# | App | Category | Rating | Reviews | Size | Installs | Type | Price | Content Rating | Genres | Last Updated | Current Ver | Android Ver |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | Facebook | SOCIAL | 4.1 | 78158306 | Varies with device | 1,000,000,000+ | Free | 0.0 | Teen | Social | August 3, 2018 | Varies with device | Varies with device |
#
# ### App
# - Application name
#
# ### Category
# - The category the app belongs to
#
# ### Rating
# - Number of user reviews for the app (as when scraped)
#
# ### Reviews
# - Number of user reviews for the app (as when scraped)
#
# ### Installs
# - Number of user downloads/install for the app (as when scraped)
#
# ### Type
# -  Paid or Free
#
# ### Price
# - Price of the app (as when scraped)
#
# ### Content Rating
# - Age group the app is targeted at - Children / Mature 21+ / Adult
#
# ### Genres
# - An app can belong to multiple genres (apart from its main category). For example. a musical family game will belong to Music, Game, Family genres.
#
# ### Last Updated
# - Date when the app was last updated on the Play Store (as when scraped)
#
# ### Current Ver
# - Current version of the app available on Play Store (as when scraped)
#
# ### Android Ver
# - Min required Android version (as when scraped)

# %% [markdown]
# # Data Munging
#
# ## Data types
# When you look at the current version of the dataset, all of the columns are of type object:

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# We believed that the *"Reviews"* and *"Price"* columns should be of a numerical type. We would do this with the help of the function ```pandas.to_numeric()``` and the ```remove_dollar_sign()``` function in ```repair.py``` which removes the dollar sign from the prices.

# %%
# create new dataset of cleaned data of extracted dollar sign
repair.remove_dollar_sign("googleplaystore.csv", "googleplaystore2.csv")
# Out:
# repair.py: Printing done

# %%
# update the data frame
df = pd.read_csv("googleplaystore2.csv")

# convert Price to numerical
df["Price"] = pd.to_numeric(df["Price"])

# %%
# convert Reviews column to numerical
df["Reviews"] = pd.to_numeric(df["Reviews"])

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# After the fixing the data, we have converted all columns that should be numeric into numerics

# %% [markdown]
# ## Filling null values
#
# Below displays the columns that contain null values

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
# Get data rows where the value is null
null_values = df.loc[df["Rating"].isnull()]

# %%
null_values
# Out:
#                                                      App             Category  \
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 113                            Wrinkles and rejuvenation               BEAUTY
# 123                               Manicure - nail design               BEAUTY
# 126                         Skin Care and Natural Beauty               BEAUTY
# 129                  Secrets of beauty, youth and health               BEAUTY
# 130                   Recipes and tips for losing weight               BEAUTY
# 134                        Lady adviser (beauty, health)               BEAUTY
# 163                           Anonymous caller detection  BOOKS_AND_REFERENCE
# 180                  SH-02J Owner's Manual (Android 8.0)  BOOKS_AND_REFERENCE
# 185                       URBANO V 02 instruction manual  BOOKS_AND_REFERENCE
# 227                                       Y! Mobile menu             BUSINESS
# 321    【Ranobbe complete free】 Novelba - Free app tha...               COMICS
# 478                                    Truth or Dare Pro               DATING
# 479      Private Dating, Hide App- Blue for PrivacyHider               DATING
# 480                                 Ad Blocker for SayHi               DATING
# 610                                    Random Video Chat               DATING
# 613                 Random Video Chat App With Strangers               DATING
# 617             Meet With Strangers: Video Chat & Dating               DATING
# 620             Ost. Zombies Cast - New Music and Lyrics               DATING
# 621                                   Dating White Girls               DATING
# 623                                         Geeks Dating               DATING
# 624                          Live chat - free video chat               DATING
# 626                  Fishing Brain & Boating Maps Marine               DATING
# 627                                   CAM5678 Video Chat               DATING
# 628                              Video chat live advices               DATING
# 629                                       chat live chat               DATING
# 630                                    Pet Lovers Dating               DATING
# 631            Friend Find: free chat + flirt dating app               DATING
# 632                                         Latin Dating               DATING
# 635                                          Wifi Mingle               DATING
# ...                                                  ...                  ...
# 10746                                         FP Opgaver                TOOLS
# 10748                                            FP Live        COMMUNICATION
# 10751                                          FP Market               FAMILY
# 10759                                     FP NFC Rewrite                TOOLS
# 10761                             Greek Bible FP (Audio)  BOOKS_AND_REFERENCE
# 10762                                      The FP Shield   NEWS_AND_MAGAZINES
# 10764                                  FP Transportation    AUTO_AND_VEHICLES
# 10769                                        FQ Magazine            LIFESTYLE
# 10772                     FQ Load Board for Transporters             BUSINESS
# 10773                                           FQ India            LIFESTYLE
# 10774                                            Miss FQ   NEWS_AND_MAGAZINES
# 10775                                 FQ - Football Quiz               SPORTS
# 10788    Fountain Live Wallpaper HD – Dubai Wallpaper 3D      PERSONALIZATION
# 10794                                            PopStar               FAMILY
# 10798                               Word Search Tab 1 FR               FAMILY
# 10806                                    SnakeBite911 FR              MEDICAL
# 10807                                          My FR App                TOOLS
# 10808                                 lesparticuliers.fr            LIFESTYLE
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10813                                     DICT.fr Mobile             BUSINESS
# 10816                                 FieldBi FR Offline             BUSINESS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10835                                           FR Forms             BUSINESS
# 10838                             Parkinson Exercices FR              MEDICAL
#
#        Rating  Reviews   Size  Installs  Type  Price Content Rating  \
# 23        NaN       61   7.0M  100,000+  Free   0.00       Everyone
# 113       NaN      182   5.7M  100,000+  Free   0.00   Everyone 10+
# 123       NaN      119   3.7M   50,000+  Free   0.00       Everyone
# 126       NaN      654   7.4M  100,000+  Free   0.00           Teen
# 129       NaN       77   2.9M   10,000+  Free   0.00     Mature 17+
# 130       NaN       35   3.1M   10,000+  Free   0.00   Everyone 10+
# 134       NaN       30   9.9M   10,000+  Free   0.00     Mature 17+
# 163       NaN      161   2.7M   10,000+  Free   0.00       Everyone
# 180       NaN        2   7.2M   50,000+  Free   0.00       Everyone
# 185       NaN      114   7.3M  100,000+  Free   0.00       Everyone
# 227       NaN        9   1.2M  100,000+  Free   0.00       Everyone
# 321       NaN     1330    22M   50,000+  Free   0.00       Everyone
# 478       NaN        0    20M       50+  Paid   1.49           Teen
# 479       NaN        0    18k      100+  Paid   2.99       Everyone
# 480       NaN        4   1.2M      100+  Paid   3.99           Teen
# 610       NaN        3    16M    1,000+  Free   0.00     Mature 17+
# 613       NaN        3   4.8M    1,000+  Free   0.00     Mature 17+
# 617       NaN        2   3.7M      500+  Free   0.00     Mature 17+
# 620       NaN        1   4.6M      100+  Free   0.00           Teen
# 621       NaN        0   3.6M       50+  Free   0.00     Mature 17+
# 623       NaN        0    13M       50+  Free   0.00     Mature 17+
# 624       NaN        1   8.7M      500+  Free   0.00     Mature 17+
# 626       NaN        3   6.9M      500+  Free   0.00       Everyone
# 627       NaN        0    39M      500+  Free   0.00     Mature 17+
# 628       NaN        0   8.0M      100+  Free   0.00       Everyone
# 629       NaN       24   3.9M    1,000+  Free   0.00     Mature 17+
# 630       NaN        0    14M       10+  Free   0.00     Mature 17+
# 631       NaN       23    11M      100+  Free   0.00     Mature 17+
# 632       NaN        0    13M       10+  Free   0.00     Mature 17+
# 635       NaN        0  10.0M       10+  Free   0.00       Everyone
# ...       ...      ...    ...       ...   ...    ...            ...
# 10746     NaN        9    61M    1,000+  Free   0.00       Everyone
# 10748     NaN        0   3.3M       10+  Free   0.00           Teen
# 10751     NaN       24    44k    1,000+  Free   0.00       Everyone
# 10759     NaN       17    67k    1,000+  Free   0.00       Everyone
# 10761     NaN        5   8.0M    1,000+  Free   0.00       Everyone
# 10762     NaN        0    11M       10+  Free   0.00       Everyone
# 10764     NaN        1   885k        1+  Free   0.00       Everyone
# 10769     NaN        1    12M      100+  Free   0.00       Everyone
# 10772     NaN        0   3.9M      100+  Free   0.00       Everyone
# 10773     NaN        0   8.9M       10+  Free   0.00       Everyone
# 10774     NaN        0    36M       10+  Free   0.00       Everyone
# 10775     NaN        1   9.0M        1+  Free   0.00       Everyone
# 10788     NaN        1    20M      500+  Free   0.00       Everyone
# 10794     NaN       13   5.7M    1,000+  Free   0.00       Everyone
# 10798     NaN        0  1020k       50+  Paid   1.04       Everyone
# 10806     NaN        1    42M      500+  Free   0.00       Everyone
# 10807     NaN        2   4.2M      100+  Free   0.00       Everyone
# 10808     NaN       96   1.0M   50,000+  Free   0.00       Everyone
# 10811     NaN        4   3.9M      100+  Free   0.00       Everyone
# 10813     NaN       20   2.7M   10,000+  Free   0.00       Everyone
# 10816     NaN        2   6.8M      100+  Free   0.00       Everyone
# 10818     NaN       96   1.5M   10,000+  Free   0.00       Everyone
# 10821     NaN        6   2.5M       50+  Free   0.00       Everyone
# 10822     NaN        0   3.1M       10+  Free   0.00       Everyone
# 10823     NaN        1   2.9M      100+  Free   0.00       Everyone
# 10824     NaN       67    82M   10,000+  Free   0.00       Everyone
# 10825     NaN        7   7.7M      100+  Free   0.00           Teen
# 10831     NaN       38   9.8M    5,000+  Free   0.00       Everyone
# 10835     NaN        0   9.6M       10+  Free   0.00       Everyone
# 10838     NaN        3   9.5M    1,000+  Free   0.00       Everyone
#
#                                 Genres        Last Updated Current Ver  \
# 23     Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113                             Beauty  September 20, 2017         8.0
# 123                             Beauty       July 23, 2018         1.3
# 126                             Beauty       July 17, 2018        1.15
# 129                             Beauty      August 8, 2017         2.0
# 130                             Beauty   December 11, 2017         2.0
# 134                             Beauty    January 24, 2018         3.0
# 163                  Books & Reference       July 13, 2018         1.0
# 180                  Books & Reference       June 15, 2018         3.0
# 185                  Books & Reference      August 7, 2015         1.1
# 227                           Business       April 9, 2018       1.0.5
# 321                             Comics        July 3, 2018       6.1.1
# 478                             Dating   September 1, 2017         1.0
# 479                             Dating       July 25, 2017       1.0.1
# 480                             Dating      August 2, 2018         1.2
# 610                             Dating       July 15, 2018        4.20
# 613                             Dating       July 17, 2018          1.
# 617                             Dating       July 16, 2018          1.
# 620                             Dating       July 20, 2018         1.0
# 621                             Dating       July 20, 2018         1.0
# 623                             Dating       July 10, 2018         1.0
# 624                             Dating       July 23, 2018        3.52
# 626                             Dating       July 23, 2018         1.0
# 627                             Dating       July 13, 2018       5.5.8
# 628                             Dating       July 10, 2018         1.0
# 629                             Dating       July 26, 2018         1.0
# 630                             Dating        July 9, 2018         1.0
# 631                             Dating       July 31, 2018         1.0
# 632                             Dating        July 9, 2018         1.0
# 635                             Dating       July 27, 2018         1.3
# ...                                ...                 ...         ...
# 10746                            Tools        May 31, 2018         1.9
# 10748                    Communication    November 3, 2017       1.2.4
# 10751                        Education       June 17, 2012         1.0
# 10759                            Tools    January 29, 2016         1.1
# 10761                Books & Reference     August 29, 2016       1.0.0
# 10762                 News & Magazines    February 1, 2018       1.1.0
# 10764                  Auto & Vehicles       March 9, 2018      10.0.0
# 10769                        Lifestyle   December 12, 2016         1.0
# 10772                         Business   February 16, 2018       1.1.3
# 10773                        Lifestyle       July 31, 2018       7.2.2
# 10774                 News & Magazines       April 5, 2018         3.8
# 10775                           Sports        May 29, 2018         1.0
# 10788                  Personalization      April 13, 2018         1.0
# 10794                           Casual     January 3, 2018         1.6
# 10798                           Puzzle    February 6, 2012         1.1
# 10806                          Medical     October 9, 2017         1.2
# 10807                            Tools       April 9, 2018  1.283.0037
# 10808                        Lifestyle   November 25, 2014         1.5
# 10811                  Auto & Vehicles       July 24, 2018       1.3.6
# 10813                         Business       July 17, 2018      2.1.10
# 10816                         Business      August 6, 2018       2.1.8
# 10818                          Finance        May 19, 2016         2.3
# 10821                    Entertainment        May 29, 2018         1.0
# 10822                     Productivity    December 1, 2017           1
# 10823          Video Players & Editors      April 22, 2018         1.0
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10835                         Business  September 29, 2016       1.1.5
# 10838                          Medical    January 20, 2017         1.0
#
#         Android Ver
# 23       4.1 and up
# 113      3.0 and up
# 123      4.1 and up
# 126      4.1 and up
# 129      2.3 and up
# 130      3.0 and up
# 134      3.0 and up
# 163      2.3 and up
# 180      6.0 and up
# 185      5.1 and up
# 227      6.0 and up
# 321      4.2 and up
# 478      4.0 and up
# 479      4.0 and up
# 480    4.0.3 and up
# 610    4.0.3 and up
# 613      4.0 and up
# 617      4.0 and up
# 620    4.0.3 and up
# 621      4.0 and up
# 623      4.1 and up
# 624    4.0.3 and up
# 626    4.0.3 and up
# 627    4.0.3 and up
# 628      3.0 and up
# 629      4.0 and up
# 630      4.1 and up
# 631      4.4 and up
# 632      4.1 and up
# 635      4.4 and up
# ...             ...
# 10746  4.0.3 and up
# 10748    4.2 and up
# 10751    1.6 and up
# 10759    4.0 and up
# 10761  4.0.3 and up
# 10762    4.4 and up
# 10764    4.0 and up
# 10769    4.1 and up
# 10772    5.0 and up
# 10773    4.1 and up
# 10774    4.4 and up
# 10775    5.0 and up
# 10788    4.1 and up
# 10794    4.3 and up
# 10798    3.0 and up
# 10806    4.1 and up
# 10807  2.3.3 and up
# 10808    2.3 and up
# 10811   4.4W and up
# 10813    4.1 and up
# 10816    4.1 and up
# 10818    2.2 and up
# 10821  4.0.3 and up
# 10822    4.4 and up
# 10823  4.0.3 and up
# 10824    4.4 and up
# 10825    4.0 and up
# 10831    4.0 and up
# 10835    4.0 and up
# 10838    2.2 and up
#
# [1474 rows x 13 columns]

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            1
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %% [markdown]
# According from the data above, there are 1474 rows with null values for **Rating**. This was quite problematic as this field is key for our predictive modelling later on. It does not make it any better that these null values make up about %13.5 of the total dataset. There are options to reduce the impact and the two biggest are to get the mean of the Rating column or to just delete them. There are obvious problems to these:
# 1. Deleting all 1474 ratings may have an effect of the performance of the maching learning algorithms later which is made way worse by the fact that the Ratings column will be a key attribute that we will be using for the predictives model later
# 2. Getting the mean of the entire  Rating column may not accurately represent the true rating for the null data rows
#
# There are a couple of workarounds that we have thought of:
# - Get the mean of non null values for each category and use them to to replace the null values of the categories
# - If there are very little number of null value rows for a category, they will be deleted

# %%
def fill_null_ratings_for_category(df):
    # Get all unique values for the category column
    categories = df["Category"].unique().tolist()
    
    df.isnull()
    
    for category in categories:
        cat = df.loc[df["Category"] == category]
        
        # get rows of current category where ratings is not null 
        cat_not_null = cat.loc[cat["Rating"].notna()]
        avg = cat_not_null["Rating"].mean()
        
        df.loc[df["Category"] == category, "Rating"] = df.loc[df["Category"] == category, "Rating"].fillna(avg)
    
    
        
    

fill_null_ratings_for_category(df)

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            1
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
# Out:
# App                   0
# Category              0
# Rating            10841
# Reviews               0
# Size                  0
# Installs              0
# Type                  1
# Price                 0
# Content Rating        0
# Genres                1
# Last Updated          0
# Current Ver           8
# Android Ver           2
# dtype: int64

# %%
beauty_cat_null
# Out:
#                                                    App Category  Rating  \
# 478                                  Truth or Dare Pro   DATING     NaN
# 479    Private Dating, Hide App- Blue for PrivacyHider   DATING     NaN
# 480                               Ad Blocker for SayHi   DATING     NaN
# 610                                  Random Video Chat   DATING     NaN
# 613               Random Video Chat App With Strangers   DATING     NaN
# 617           Meet With Strangers: Video Chat & Dating   DATING     NaN
# 620           Ost. Zombies Cast - New Music and Lyrics   DATING     NaN
# 621                                 Dating White Girls   DATING     NaN
# 623                                       Geeks Dating   DATING     NaN
# 624                        Live chat - free video chat   DATING     NaN
# 626                Fishing Brain & Boating Maps Marine   DATING     NaN
# 627                                 CAM5678 Video Chat   DATING     NaN
# 628                            Video chat live advices   DATING     NaN
# 629                                     chat live chat   DATING     NaN
# 630                                  Pet Lovers Dating   DATING     NaN
# 631          Friend Find: free chat + flirt dating app   DATING     NaN
# 632                                       Latin Dating   DATING     NaN
# 635                                        Wifi Mingle   DATING     NaN
# 637                    Soy Luna - Top Music And Lyrics   DATING     NaN
# 638                          When Will You Get Married   DATING     NaN
# 639                              HOW TO ASK A GIRL OUT   DATING     NaN
# 683        3   4.8M   1,000+  Free   0.00     Mature 17+  Dating
# 698        8   9.3M   5,000+  Free   0.00     Mature 17+  Dating
#
#           Last Updated Current Ver   Android Ver
# 478  September 1, 2017         1.0    4.0 and up
# 479      July 25, 2017       1.0.1    4.0 and up
# 480     August 2, 2018         1.2  4.0.3 and up
# 610      July 15, 2018        4.20  4.0.3 and up
# 613      July 17, 2018          1.    4.0 and up
# 617      July 16, 2018          1.    4.0 and up
# 620      July 20, 2018         1.0  4.0.3 and up
# 621      July 20, 2018         1.0    4.0 and up
# 623      July 10, 2018         1.0    4.1 and up
# 624      July 23, 2018        3.52  4.0.3 and up
# 626      July 23, 2018         1.0  4.0.3 and up
# 627      July 13, 2018       5.5.8  4.0.3 and up
# 628      July 10, 2018         1.0    3.0 and up
# 629      July 26, 2018         1.0    4.0 and up
# 630       July 9, 2018         1.0    4.1 and up
# 631      July 31, 2018         1.0    4.4 and up
# 632       July 9, 2018         1.0    4.1 and up
# 635      July 27, 2018         1.3    4.4 and up
# 637      July 24, 2018         1.0  4.0.3 and up
# 638      July 14, 2018         1.0  4.0.3 and up
# 639      July 16, 2018         1.0  4.0.3 and up
# 641     August 2, 2018         1.2    4.1 and up
# 642      July 12, 2018         1.0    4.1 and up
# 643      July 22, 2018       1.0.7    4.0 and up
# 644      July 26, 2018         1.0  4.0.3 and up
# 647      July 11, 2018         1.0    3.0 and up
# 648     August 3, 2018         8.2  4.0.3 and up
# 649      July 31, 2018         2.0  4.0.3 and up
# 650      July 24, 2018       1.0.3    4.2 and up
# 651      July 22, 2018   3.5.4.2.3    4.1 and up
# 652      July 17, 2018       1.1.1    4.2 and up
# 653      July 30, 2018         1.6    4.1 and up
# 658      July 19, 2018       4.5.0  4.0.3 and up
# 659      July 12, 2018         6.1    4.0 and up
# 660       July 9, 2018         3.0  4.0.3 and up
# 666      July 15, 2018        4.20  4.0.3 and up
# 669      July 27, 2018       1.0.2  4.0.3 and up
# 683      July 17, 2018          1.    4.0 and up
# 698       July 2, 2018         3.7  4.0.3 and up

# %%
beauty_cat_not_null
# Out:
#                                                      App Category  Rating  \
# 476                            Moco+ - Chat, Meet People   DATING     4.2
# 477                                           Calculator   DATING     2.6
# 481    AMBW Dating App: Asian Men Black Women Interra...   DATING     3.5
# 482                       Zoosk Dating App: Meet Singles   DATING     4.0
# 483                                       OkCupid Dating   DATING     4.1
# 484                         Match™ Dating - Meet Singles   DATING     3.7
# 485            Hily: Dating, Chat, Match, Meet & Hook up   DATING     4.1
# 486                        Hinge: Dating & Relationships   DATING     4.2
# 487              Casual Dating & Adult Singles - Joyride   DATING     4.5
# 488                          BBW Dating & Plus Size Chat   DATING     4.4
# 489                             Moco - Chat, Meet People   DATING     4.2
# 490                                  CMB Free Dating App   DATING     4.0
# 491                  Hot or Not - Find someone right now   DATING     4.1
# 492                         eharmony - Online Dating App   DATING     3.1
# 493    Free Dating App & Flirt Chat - Match with Singles   DATING     4.4
# 494    Chispa, the Dating App for Latino, Latina Singles   DATING     4.2
# 495                                    Clover Dating App   DATING     4.1
# 496                       Black People Meet Singles Date   DATING     3.9
# 477    Dating   October 25, 2017               1.1.6          4.0 and up
# 481    Dating   January 21, 2017               1.0.1          4.0 and up
# 482    Dating     August 2, 2018  Varies with device  Varies with device
# 483    Dating      July 30, 2018             11.10.1          4.1 and up
# 484    Dating      July 23, 2018  Varies with device  Varies with device
# 485    Dating     August 1, 2018               2.5.2          4.1 and up
# 486    Dating     August 3, 2018               6.1.3          5.0 and up
# 487    Dating      July 31, 2018              4.17.2          4.1 and up
# 488    Dating      July 27, 2018             3.5.0.1          4.1 and up
# 489    Dating     August 4, 2018             2.6.141          4.1 and up
# 490    Dating     August 1, 2018         4.19.0.2320          4.4 and up
# 491    Dating     August 2, 2018  Varies with device  Varies with device
# 492    Dating      July 30, 2018               6.6.5          4.1 and up
# 493    Dating     August 4, 2018               1.639          4.0 and up
# 494    Dating      July 25, 2018               1.6.1          4.4 and up
# 495    Dating      July 24, 2018               2.5.1          4.1 and up
# 496    Dating      July 25, 2018               1.9.7          4.4 and up
# 497    Dating     August 3, 2018                4.4B          4.1 and up
# 498    Dating     August 3, 2018            1.308.us          4.1 and up
# 499    Dating       July 7, 2018               2.4.1          4.1 and up
# 500    Dating     August 1, 2018  Varies with device  Varies with device
# 501    Dating   January 27, 2017               5.0.1          4.2 and up
# 502    Dating      July 31, 2018              4.17.2          4.1 and up
# 503    Dating      July 17, 2018                2.45          4.1 and up
# 504    Dating      July 25, 2018               1.6.1          4.4 and up
# 505    Dating       July 3, 2018               4.5.5          4.1 and up
# 506    Dating      June 19, 2018               1.0.4          4.4 and up
# 507    Dating       June 6, 2018               1.2.1          4.1 and up
# 508    Dating      July 24, 2018  Varies with device  Varies with device
# ...       ...                ...                 ...                 ...
# 678    Dating      July 17, 2018               1.0.0          4.4 and up
# 679    Dating      July 26, 2018              12.0.4          4.1 and up
# 680    Dating      July 16, 2018                 8.2        4.0.3 and up
# 681    Dating   November 6, 2017                 1.0        4.0.3 and up
# 682    Dating      July 16, 2018                 2.4        4.0.3 and up
# 684    Dating       July 9, 2018                 1.2          4.1 and up
# 685    Dating       July 8, 2018                 8.2        4.0.3 and up
# 686    Dating       May 15, 2018                 8.2        4.0.3 and up
# 687    Dating       July 9, 2018                 8.2        4.0.3 and up
# 688    Dating     April 21, 2018                 8.2        4.0.3 and up
# 689    Dating      June 28, 2018                 8.2        4.0.3 and up
# 690    Dating  December 28, 2017               1.0.5          4.0 and up
# 691    Dating     August 4, 2018              1.0.82          4.4 and up
# 692    Dating       July 5, 2018                 8.2        4.0.3 and up
# 693    Dating     August 2, 2018               1.0.5          4.0 and up
# 694    Dating      July 10, 2018                 4.1          4.1 and up
# 695    Dating     August 2, 2018               5.0.8          4.1 and up
# 696    Dating   January 27, 2017               5.0.1          4.2 and up
# 697    Dating      July 10, 2018               1.230        4.0.3 and up
# 4195   Dating      July 29, 2018               2.1.6          5.0 and up
# 4441   Dating      July 19, 2018               1.0.1          4.3 and up
# 6271   Dating  November 29, 2016               1.0.6          4.1 and up
# 6286   Dating     August 4, 2018             2.6.142          4.1 and up
# 6288   Dating     August 2, 2018  Varies with device  Varies with device
# 6302   Dating      July 30, 2018             11.10.1          4.1 and up
# 7077   Dating     August 2, 2018  Varies with device  Varies with device
# 7303   Dating      July 10, 2017               1.0.2          2.3 and up
# 10045  Dating     April 12, 2017                 1.1        4.0.3 and up
# 10168  Dating  February 16, 2018               4.4.1          4.1 and up
# 10715  Dating  February 25, 2016                 2.2          4.0 and up
#
# [195 rows x 13 columns]

# %%
# Out:
# ['ART_AND_DESIGN',
#  'AUTO_AND_VEHICLES',
#  'BEAUTY',
#  'BOOKS_AND_REFERENCE',
#  'BUSINESS',
#  'COMICS',
#  'COMMUNICATION',
#  'DATING',
#  'EDUCATION',
#  'ENTERTAINMENT',
#  'EVENTS',
#  'FINANCE',
#  'FOOD_AND_DRINK',
#  'HEALTH_AND_FITNESS',
#  'HOUSE_AND_HOME',
#  'LIBRARIES_AND_DEMO',
#  'LIFESTYLE',
#  'GAME',
#  'FAMILY',
#  'MEDICAL',
#  'SOCIAL',
#  'SHOPPING',
#  'PHOTOGRAPHY',
#  'SPORTS',
#  'TRAVEL_AND_LOCAL',
#  'TOOLS',
#  'PERSONALIZATION',
#  'PRODUCTIVITY',
#  'PARENTING',
#  'WEATHER',
#  'VIDEO_PLAYERS',
#  'NEWS_AND_MAGAZINES',
#  'MAPS_AND_NAVIGATION']

# %%
print()
# Out:
# 98       4.7
# 99       4.9
# 100      4.7
# 101      3.9
# 102      3.9
# 103      4.2
# 104      4.6
# 105      4.3
# 106      4.7
# 107      4.7
# 108      4.8
# 109      4.2
# 110      4.3
# 111      4.5
# 112      4.1
# 113      4.2
# 114      4.2
# 115      4.5
# 116      4.4
# 117      4.0
# 118      4.1
# 119      4.1
# 120      4.4
# 121      4.6
# 122      4.5
# 123      4.2
# 124      3.9
# 125      4.4
# 126      4.2
# 127      4.6
# 128      3.8
# 129      4.2
# 130      4.2
# 131      4.0
# 132      4.3
# 133      4.5
# 134      4.2
# 135      4.1
# 136      3.7
# 137      4.7
# 138      4.2
# 5192     3.1
# 5998     4.2
# 6222     4.0
# 6318     4.2
# 6506     4.0
# 6828     4.2
# 7021     4.5
# 7460     4.2
# 8505     4.2
# 9205     4.0
# 10022    4.7
# 10289    3.9
# Name: Rating, dtype: float64

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.loc[df["Category"] == "BEAUTY", "Rating"]
# Out:
# 98       4.7
# 99       4.9
# 100      4.7
# 101      3.9
# 102      3.9
# 103      4.2
# 104      4.6
# 105      4.3
# 106      4.7
# 107      4.7
# 108      4.8
# 109      4.2
# 110      4.3
# 111      4.5
# 112      4.1
# 113      NaN
# 114      4.2
# 115      4.5
# 116      4.4
# 117      4.0
# 118      4.1
# 119      4.1
# 120      4.4
# 121      4.6
# 122      4.5
# 123      NaN
# 124      3.9
# 125      4.4
# 126      NaN
# 127      4.6
# 128      3.8
# 129      NaN
# 130      NaN
# 131      4.0
# 132      4.3
# 133      4.5
# 134      NaN
# 135      4.1
# 136      3.7
# 137      4.7
# 138      4.2
# 5192     3.1
# 5998     NaN
# 6222     4.0
# 6318     NaN
# 6506     4.0
# 6828     NaN
# 7021     4.5
# 7460     NaN
# 8505     NaN
# 9205     4.0
# 10022    4.7
# 10289    3.9
# Name: Rating, dtype: float64
